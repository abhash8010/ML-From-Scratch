# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#      x      y
# 0   85  297.2
# 1   22  117.4
# 2  148  534.8
# 3    7   11.4
# 4  113  428.4

# %%
plt.scatter(data.x, data.y)
plt.show()

# %%
# Loss Function
def loss_func(m, b, points):
    error = 0
    for i in range(len(points)):
        x = points.iloc[i].x
        y = points.iloc[i].y
        error += (y - (m * x + b)) ** 2
    return error/ len(points)

# %%
# Gradient Descent

def gradient_descent(m_now, b_now, points, L):
    m_gradient, b_gradient = 0, 0
    
    n = len(points)
    for i in range (n):
        x = points.iloc[i].x
        y = points.iloc[i].y
        
        m_gradient += -(2/n) * x * (y - m_now * x + b_now)
        b_gradient += -(2/n) * (y - m_now * x + b_now)
    m = m_now - m_gradient * L
    b = b_now - b_gradient * L
    
    return m, b

# %%
m = 0
b = 0
L = 0.0001
epochs = 1000

for i in range(epochs):
    if i % 50 == 0:
        print(f'This is epoch {i}')
    m, b = gradient_descent(m, b, data, L)
print(m, b)

plt.scatter(data.x, data.y, color='black')
plt.plot(list(range(0,150)), [m * x + b for x in range(0, 150)], color='red')
plt.show()
# Out:
# This is epoch 0
# This is epoch 50
# This is epoch 100
# This is epoch 150
# This is epoch 200
# This is epoch 250
# This is epoch 300
# This is epoch 350
# This is epoch 400
# This is epoch 450
# This is epoch 500
# This is epoch 550
# This is epoch 600
# This is epoch 650
# This is epoch 700
# This is epoch 750
# This is epoch 800
# This is epoch 850
# This is epoch 900
# This is epoch 950
# 3.684620648001637 0.6695593701781227
